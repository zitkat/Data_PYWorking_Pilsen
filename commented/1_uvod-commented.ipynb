# %% [markdown]
# # Jupyter Notebook
#
# Jupyter Notebook je interaktivní prostředí, ve kterém může být pod sebou obyčejný text a spustitelný (Pythonní) kód. Text i k=od je členěn do buněk, kód je v buňkách typu `code` text v buňkách typu `markdown`. Tohle je `markdown` buňka stejně jako několik následujicích, první `code` buňka je ta s `import sys`.
#
# V textových buňkách se dá používat všelijaké formatování a dokonce i LaTeX. Když dvakrát klikneš na buňky níže zobrazí se ti jejich "zdrojový kód". Příklady níže zahrnují několik způsobů formátování, které by ti mohli na lecco vystačit.
#
# Aby se opět zobrazil zformátovaný obsah buněk stačí stisknout `Shift + Enter` nebo `Crtl + Enter`, Shit tě posune na další buňku Crtl zůstane na té současné.
#
# Stejně se spouští Pythonní kód v buňce. Výstup se vypíše pod buňku a zůstane pod ní dokud ji znovu nespustíš nebo ho nevymažeš.
#
# Díky jejich povaze existuje i spousta způsobů jak notebooky sdílet a spouštět vzdáleně přes internet, například
# https://colab.research.google.com/notebooks/basic_features_overview.ipynb#scrollTo=d-S-3nYLQSHb
# nebo si můžete nastavit vlastní server.
#
# Github je taky umí zobrazovat.

# %% [markdown]
# # O malém hřišti na velké planetě
# ###### aneb planetární fotbalová liga
# * Na Jupiteru se fotbal hraje s *golfovým míčkem* obyčejný míč by bylo totiž moc **těžký**
# * Nikdo by hřiště nepřekopl, protože gravitační zrychlení
#
# $$ g = \kappa \frac{Mm}{r^2},$$
#
# je na Jupyteru $2.4$-krát větší než na Zemi.
#
# Ke hře je potřeba
#
# 1. 11 + 11 marťanů nebo pozemšťanů vybavených skafandry.
# 2. Auty je třeba vrhat katapultem.
# 3. Rozhodčím je sonda Voyager 2.
# 4. Ta ovšem už opustila sluneční soustavu a tak písknutí následuje vždy až 6 hodin po zákroku.

# %% [markdown]
# $$ c = \sqrt{a^2 + b^2}$$

# %% [markdown]
# [To the github!](https://github.com/zitkat/Data_PYWorking_Pilsen)

# %% [markdown]
# ## Python je na Jupyteru jako doma:

# %%
import sys

# %%
sys.executable
# Out:
# 'C:\\Anaconda3\\python.exe'

# %%
g = 9.81 * 2.4

# %%
print("Fotbalový míč na Jupiteru váží {} kg".format(2.4 * .5))
# Out:
# Fotbalový míč na Jupiteru váží 1.2 kg

# %%
kdo = input("Kdo? >")

# %%
kdo
# Out:
# 'Tomáš'

# %%
neco = input("Řekni něco> ")
neco_dalsiho = input("Rekni neco dalsiho ")
print(neco, neco_dalsiho)
# Out:
# Řekni něco> nic
# Rekni neco dalsiho nic dalsiho
# nic nic dalsiho

# %% [markdown]
# ## Řetězení voláni a indexace
# Vyrobíme se trochu složitější datovou strukturu, abychom měli s čím pracovat.

# %%
hraci = [{"jméno": "Robot", "příjmení": "Marvin", "číslo": -42 , "tým": "FC Cadia"},
         {"jméno": "Leman", "příjmení": "Russ", "číslo": 40001, "tým": "FC Cadia" },
         {"jméno": "Zafod", "příjmení": "Biblbrox", "číslo": 42, "tým": "FC Cadia" },
         {"jméno": "Rick", "příjmení": "Sanchez", "číslo": 8, "tým": "FC Terra"},
         {"jméno": "Morty", "příjmení": "Sanchez", "číslo": 0, "tým": "FC Terra"}
]

# %%
hrac_1 = hraci[1]

# %%
hrac1
# Out:
# {'jméno': 'Leman', 'příjmení': 'Russ', 'číslo': 40001, 'tým': 'FC Cadia'}

# %%
hrac1["jméno"]
# Out:
# 'Leman'

# %%
hraci[1]["jméno"].lower()[0]
# Out:
# 'l'

# %% [markdown]
# ## Magic?

# %%
# %pwd
# Out:
# 'C:\\Users\\tomas\\PycharmProjects\\Data_PYWorking_Pilsen'

# %%
# %cd ..
# Out:
# C:\Users\tomas\PycharmProjects

# %%
# %pwd
# Out:
# 'C:\\Users\\tomas\\PycharmProjects'

# %%
# %cd JuPa_PyWorking/
# Out:
# [WinError 2] Systém nemůže nalézt uvedený soubor: 'JuPa_PyWorking/'
# C:\Users\tomas\PycharmProjects

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 78E7-0370
#
#  Directory of C:\Users\tomas\PycharmProjects
#
# 01.05.2019  11:35    <DIR>          .
# 01.05.2019  11:35    <DIR>          ..
# 10.12.2018  22:35             8˙048 .emacs.desktop
# 24.04.2019  19:18    <DIR>          .ipynb_checkpoints
# 28.04.2019  22:38    <DIR>          Combinatorics
# 16.02.2019  10:05    <DIR>          Data_analysis_workshop
# 19.08.2019  18:29    <DIR>          Data_PYWorking_Pilsen
# 14.09.2017  18:18    <DIR>          hcenat-bq-analysis
# 29.04.2017  21:47    <DIR>          logan
# 06.09.2017  18:30    <DIR>          mazeanalysis
# 17.11.2018  13:36             4˙251 mypy2.yml
# 17.11.2018  13:37             2˙915 mypy3.yml
# 06.02.2019  18:38    <DIR>          naucse.python.cz
# 27.11.2016  00:00    <DIR>          py-databases_course
# 06.08.2019  08:57    <DIR>          pyLadies
# 23.04.2019  09:36    <DIR>          PyLadies_HWs_git
# ...

# %%
# %ls -l
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 78E7-0370
#
#  Directory of C:\Users\tomas\PycharmProjects
# File Not Found

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 78E7-0370
#
#  Directory of C:\Users\tomas\PycharmProjects
#
# 01.05.2019  11:35    <DIR>          .
# 01.05.2019  11:35    <DIR>          ..
# 10.12.2018  22:35             8˙048 .emacs.desktop
# 24.04.2019  19:18    <DIR>          .ipynb_checkpoints
# 28.04.2019  22:38    <DIR>          Combinatorics
# 16.02.2019  10:05    <DIR>          Data_analysis_workshop
# 19.08.2019  18:29    <DIR>          Data_PYWorking_Pilsen
# 14.09.2017  18:18    <DIR>          hcenat-bq-analysis
# 29.04.2017  21:47    <DIR>          logan
# 06.09.2017  18:30    <DIR>          mazeanalysis
# 17.11.2018  13:36             4˙251 mypy2.yml
# 17.11.2018  13:37             2˙915 mypy3.yml
# 06.02.2019  18:38    <DIR>          naucse.python.cz
# 27.11.2016  00:00    <DIR>          py-databases_course
# 06.08.2019  08:57    <DIR>          pyLadies
# 17.11.2018  13:36               722 pyladies37.yml
# ...

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...
